# %%
import pandas as pd
from random import randint
import random
import csv
import os
from class_struggle_automatic import Game, Board, Player

# %% [markdown]
# # Snapshot of card draws

# %%
capitalist_cards = pd.read_csv('capitalist_chance_cards.csv')
capitalist_cards.head()
# Out:
#                                               prompt  asset  debit  position  \
# 0  Most Government welfare goes to Big Business (...      2      0         0
# 1  Sexually repressed people generally make good,...      2      0         0
# 2  In an effort to balance the budget, your schoo...      2      0         0
# 3  Tax Refund: many big corporations don’t pay an...      4      0         0
# 4  Skill at red baiting, getting workers to fight...      1      0         0
#
#    turn action
# 0     0  asset
# 1     0  asset
# 2     0  asset
# 3     0  asset
# 4     0  asset

# %%
worker_cards = pd.read_csv('worker_chance_cards.csv')
worker_cards.head()
# Out:
#                                               prompt  asset  debit  position  \
# 0  Your boss died, but the new one acts in much t...      1      0         0
# 1  Socialist ideas are spreading in the army - wo...      3      0         0
# 2  Workers finally understand that, with America’...      3      0         0
# 3  Candidate carter promised to reduce the Defens...      1      0         0
# 4  You know your interest and the interests of th...      5      0         0
#
#    turn action
# 0     0  asset
# 1     0  asset
# 2     0  asset
# 3     0  asset
# 4     0  asset

# %% [markdown]
# # Example Automatic Play-through

# %%
Game(2)
# Out:
# --------------------------------------------------
# Game initialized! The last space is at position 84.
# Whoever gets to that space first wins!
# --------------------------------------------------
# --------------------------------------------------
# Players initialized! This is a 2-player game.
# --------------------------------------------------
# --------------------------------------------------
# Capitalist's turn! Start Position: 0
# ┌─────┐
# │ o   │
# │  o  │
# │   o │
# └─────┘
# A 3 was rolled!
#
# Increase in position by 3.
# Assets     Debits     Position
# 0          0          3
#
# Now, Draw a card!
# ┌─────────────────────────────────────────────────┐
# │ Farmers are fooled into blaming consumers       │
# │ (instead of the profits of Capitalist middlemen)│
# │ for the low prices they get for their           │
# │ crops. Move 1 space.                            │
# └─────────────────────────────────────────────────┘
# Your position changes by 1.
#
# ...
